# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels as sm

# %%
df = pd.read_excel('merged17-19.xlsx')
df = df.iloc[1:]
dic = list(df.columns)
col_dict = dict(zip(dic, ['week', 'total','upto17', '18-29', '30-64', '65+', 'hospital', 'indicator', 'epid', 'epid excess']))
df = df.rename(columns = col_dict, inplace = False)
df[['week', 'total', 'upto17', '18-29', '30-64', '65+', 'hospital']] \
= df[['week', 'total', 'upto17', '18-29', '30-64', '65+', 'hospital']].astype(int)
# df.set_index('week', inplace=True, drop=True)
df[20:52]
# Out:
#     week  total  upto17  18-29  30-64   65+  hospital  indicator    epid  \
# 21     9  13761    9545   1189   2466   561       231     512.41  854.78
# 22    10   8265    5011    874   1898   482       219     307.76  807.04
# 23    11   9045    5331    943   2197   574       229     336.80  671.92
# 24    12   8740    5362    904   1999   475       200     325.45  661.38
# 25    13   7454    4413    775   1752   514       168     277.56  591.14
# 26    14   6214    3729    632   1469   384       160     231.39  488.08
# 27    15   5343    3363    500   1149   331       145     198.95  518.27
# 28    16   5864    3775    524   1224   341       138     218.35  486.36
# 29    17   5932    4019    451   1161   301       132     220.89  418.65
# 30    18   3975    2658    322    783   212       142     148.01  340.46
# 31    19   3970    2645    312    816   197       118     147.83  384.56
# 32    20   3990    2649    326    795   220        69     148.57  459.97
# 33    41   5432    3618    491   1113   210       138     202.27  520.95
# 34    42   4261    2875    376    835   175       136     158.66  536.97
# 35    43   4740    3066    478    978   218       118     176.50  626.17
# 36    44   4349    2721    445    958   225       108     161.94  560.60
# 37    45   4988    3236    446   1101   205       137     185.73  564.60
# 38    46   6484    3875    607   1645   357       199     241.44  500.91
# 39    47   9776    5843    820   2554   559       261     364.02  501.71
# 40    48  15010    8132   1454   4515   909       379     558.92  501.71
# 41    49  16600    8509   1619   5275  1197       368     618.12  501.71
# 42    50  14353    7741   1357   4220  1035       289     534.45  501.71
# 43    51   9817    5485    927   2746   659       254     365.55  501.71
# 44    52   5499    3054    497   1610   338       174     204.76  501.71
# 45     1   4148    2355    401   1173   219       112     154.87  501.71
# 46     2   4463    2341    493   1326   303       129     166.63  501.71
# 47     3   5078    2850    591   1346   291       107     189.59  501.71
# 48     4   5252    3199    484   1298   271       121     196.09  501.71
# 49     5   5731    3527    538   1341   325       138     213.97  501.71
# 50     6   6493    4091    670   1448   284       132     242.42  501.71
# 51     7   6182    3938    671   1299   274       147     230.81  501.71
# 52     8   6086    3756    649   1359   322       128     227.23  501.71
#
#     epid excess
# 21       -40.05
# 22       -61.87
# 23       -49.87
# 24       -50.79
# 25       -53.05
# 26       -52.59
# 27       -61.61
# 28       -55.10
# 29       -47.24
# 30       -56.53
# 31       -61.56
# 32       -67.70
# 33       -61.17
# 34       -70.45
# 35       -71.81
# 36       -71.11
# 37       -67.10
# 38       -51.80
# 39       -27.44
# 40        11.40
# 41        23.20
# 42         6.53
# 43       -27.14
# 44       -59.19
# 45       -69.13
# 46       -66.79
# 47       -62.21
# 48       -60.92
# 49       -57.35
# 50       -51.68
# 51       -53.99
# 52       -54.71

# %%
df.iloc[:, 7:9].plot(figsize=(13,26),kind='bar', color=['red', 'blue'], fontsize=7)
df2 = df.iloc[:, 1:6]
df2.plot()
